# %% [markdown]
# 웹 기반 서비스의 사용자 행동, 설문 기반 사용자 특성 데이터

# %%
import pandas as pd

data = pd.read_csv("../chan/sample_data.csv") 
#CSV = Comma-Separated Values (쉼표로 구분된 값들)
# Out:
#              날짜 성별  지역 만족도  평균 체류 시간(분)  월 수입(만원)  방문 페이지 수  자녀 수
# 0    2024-01-01  남  대전   상         40.4     193.0         3     0
# 1    2024-01-02  여  대전   중         34.8     288.0         2     2
# 2    2024-01-03  남  서울   하         57.2     274.0         8     0
# 3    2024-01-04  남  대전   중         45.1     329.0         7     1
# 4    2024-01-05  남  서울   상         23.8     341.0         4     0
# ..          ... ..  ..  ..          ...       ...       ...   ...
# 145  2024-05-25  남  광주   중         41.5     323.0         5     0
# 146  2024-05-26  남  부산   상         57.5     336.0         4     1
# 147  2024-05-27  남  대전   중         33.5     266.0         6     1
# 148  2024-05-28  남  서울   중         33.3     358.0         8     0
# 149  2024-05-29  여  광주   하         35.2     220.0         4     0
#
# [150 rows x 8 columns]

# %%
data.head()
# Out:
#            날짜 성별  지역 만족도  평균 체류 시간(분)  월 수입(만원)  방문 페이지 수  자녀 수
# 0  2024-01-01  남  대전   상         40.4     193.0         3     0
# 1  2024-01-02  여  대전   중         34.8     288.0         2     2
# 2  2024-01-03  남  서울   하         57.2     274.0         8     0
# 3  2024-01-04  남  대전   중         45.1     329.0         7     1
# 4  2024-01-05  남  서울   상         23.8     341.0         4     0

# %%
data.tail()
# Out:
#              날짜 성별  지역 만족도  평균 체류 시간(분)  월 수입(만원)  방문 페이지 수  자녀 수
# 145  2024-05-25  남  광주   중         41.5     323.0         5     0
# 146  2024-05-26  남  부산   상         57.5     336.0         4     1
# 147  2024-05-27  남  대전   중         33.5     266.0         6     1
# 148  2024-05-28  남  서울   중         33.3     358.0         8     0
# 149  2024-05-29  여  광주   하         35.2     220.0         4     0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   날짜           150 non-null    object
#  1   성별           150 non-null    object
#  2   지역           150 non-null    object
#  3   만족도          150 non-null    object
#  4   평균 체류 시간(분)  150 non-null    float64
#  5   월 수입(만원)     150 non-null    float64
#  6   방문 페이지 수     150 non-null    int64
#  7   자녀 수         150 non-null    int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 9.5+ KB

# %%
data.describe()
# Out:
#        평균 체류 시간(분)    월 수입(만원)    방문 페이지 수        자녀 수
# count   150.000000  150.000000  150.000000  150.000000
# mean     40.494000  314.613333    5.000000    1.100000
# std       7.435659   62.724045    2.237568    0.939442
# min      14.100000  182.000000    1.000000    0.000000
# 25%      35.200000  267.250000    3.000000    0.000000
# 50%      40.300000  314.500000    5.000000    1.000000
# 75%      45.250000  357.000000    6.750000    2.000000
# max      57.500000  505.000000   11.000000    3.000000

# %%
import pandas as pd

data = pd.read_csv("../chan/sample_data.csv")
data
data.head()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   날짜           150 non-null    object
#  1   성별           150 non-null    object
#  2   지역           150 non-null    object
#  3   만족도          150 non-null    object
#  4   평균 체류 시간(분)  150 non-null    float64
#  5   월 수입(만원)     150 non-null    float64
#  6   방문 페이지 수     150 non-null    int64
#  7   자녀 수         150 non-null    int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 9.5+ KB

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
import koreanize_matplotlib

# %%
sns.countplot(data=data, x="성별")

# %%
data
# Out:
#              날짜 성별  지역 만족도  평균 체류 시간(분)  월 수입(만원)  방문 페이지 수  자녀 수
# 0    2024-01-01  남  대전   상         40.4     193.0         3     0
# 1    2024-01-02  여  대전   중         34.8     288.0         2     2
# 2    2024-01-03  남  서울   하         57.2     274.0         8     0
# 3    2024-01-04  남  대전   중         45.1     329.0         7     1
# 4    2024-01-05  남  서울   상         23.8     341.0         4     0
# ..          ... ..  ..  ..          ...       ...       ...   ...
# 145  2024-05-25  남  광주   중         41.5     323.0         5     0
# 146  2024-05-26  남  부산   상         57.5     336.0         4     1
# 147  2024-05-27  남  대전   중         33.5     266.0         6     1
# 148  2024-05-28  남  서울   중         33.3     358.0         8     0
# 149  2024-05-29  여  광주   하         35.2     220.0         4     0
#
# [150 rows x 8 columns]

# %%
data["성별"]
# Out:
# 0      남
# 1      여
# 2      남
# 3      남
# 4      남
#       ..
# 145    남
# 146    남
# 147    남
# 148    남
# 149    여
# Name: 성별, Length: 150, dtype: object

# %%
plt.figure(figsize=(3, 3))
sns.countplot(data=data, x="성별")
plt.title("성별에 대한 막대그래프")
plt.show()

# %%
plt.figure(figsize=(3, 3))
sns.countplot(data=data, x="성별")
plt.title("성별에 대한 막대그래프")
plt.show()

# %%
# "월 수입(만원)"열에 대한 히스토그램
plt.figure(figsize=(3, 3))
plt.hist(data["월 수입(만원)"], bins=14,edgecolor="black")
plt.title("월 수입(만원) 히스토그램")
plt.show()

# %%
plt.subplots(1,3, figsize=(3,3))
# Out:
# (<Figure size 300x300 with 3 Axes>,
#  array([<Axes: >, <Axes: >, <Axes: >], dtype=object))

# %%
plt.subplots(1,3, figsize=(10,3))
# Out:
# (<Figure size 1000x300 with 3 Axes>,
#  array([<Axes: >, <Axes: >, <Axes: >], dtype=object))

# %%
fig, ax = plt.subplots(1, 3, figsize=(10,3))
# 첫번째 그래프: 자녀 수에 대한 막대 그래프
sns.countplot(data=data, x="자녀 수", ax=ax[0])
ax[0].set_title("자녀 수에 대한 막대그래프")
# 두번째 그래프: 평균 체류 시간(분)에 대한 히스토그램
ax[1].hist(data["평균 체류 시간(분)"], edgecolor="black")
ax[1].set_title("평균 체류 시간(분)에 대한 히스토그램")
# 세번째 그래프: 월 수입(만원)에 대한 상자그림
ax[2].boxplot(x=data["월 수입(만원)"])
ax[2].set_title("월 수입(만원)에 대한 Box Plot")
ax[2].set_xlabel("월 수입(만원)")
# Out:
# Text(0.5, 0, '월 수입(만원)')

# %%
plt.figure(figsize=(3, 3))
sns.countplot(data=data, x="만족도", order=["하", "중", "상"])
plt.title("만족도에 대한 막대그래프")
plt.show()

# %%
plt.figure(figsize=(3, 3))
sns.countplot(data=data, x="만족도", order=["하", "중", "상"], hue="성별") #hue : 데이터에 따라 색을 다르게 입힘
plt.title("만족도에 대한 막대그래프")
plt.show()

# %% [markdown]
# 연속형 데이터

# %%
# "월 수입(만원)"열에 대한 히스토그램
plt.figure(figsize=(3, 3))
plt.hist(data["월 수입(만원)"], bins=1000, edgecolor="black")
plt.title("월 수입(만원) 히스토그램")
plt.show()

# %%
# "월 수입(만원)"열에 대한 히스토그램
plt.figure(figsize=(3, 3))
plt.hist(data["월 수입(만원)"], bins=100, edgecolor="black")
plt.title("월 수입(만원) 히스토그램")
plt.show()

# %%
# "월 수입(만원)"열에 대한 히스토그램
plt.figure(figsize=(3, 3))
plt.hist(data["월 수입(만원)"], bins=15, edgecolor="black")
plt.title("월 수입(만원) 히스토그램")
plt.show()

# %%
plt.figure(figsize=(3, 3))
plt.boxplot(data["월 수입(만원)"]), 
plt.title("월 수입(만원)에 대한 Box Plot")
plt.show()

# %%
plt.figure(figsize=(3, 3))
sns.boxplot(data=data, x = "성별", y = "월 수입(만원)", color = "orange")
plt.title("월 수입(만원)에 대한 Box Plot")
plt.show()

# %% [markdown]
# 4) 이산형 데이터

# %%
#방문 페이지 수 
## 구글링 
fig, ax = plt.subplots()
sns.countplot(data = data,x = "방문 페이지 수", ax =ax)
ax.set_title(" 방문자 페이지 수에 대한 막대그래프")
### 타이틀 작성하는 방법 ###
# Out:
# Text(0.5, 1.0, ' 방문자 페이지 수에 대한 막대그래프')

# %% [markdown]
# 5)시계열 데이터

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   날짜           150 non-null    object
#  1   성별           150 non-null    object
#  2   지역           150 non-null    object
#  3   만족도          150 non-null    object
#  4   평균 체류 시간(분)  150 non-null    float64
#  5   월 수입(만원)     150 non-null    float64
#  6   방문 페이지 수     150 non-null    int64
#  7   자녀 수         150 non-null    int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 9.5+ KB

# %% [markdown]
# * 날짜에 대한 데이터 타입은 datatime

# %%
#sample_data.csv를 불러와주세요 
data = pd.read_csv("../chan/sample_data.csv", parse_dates = ["날짜"])
data
# Out:
#             날짜 성별  지역 만족도  평균 체류 시간(분)  월 수입(만원)  방문 페이지 수  자녀 수
# 0   2024-01-01  남  대전   상         40.4     193.0         3     0
# 1   2024-01-02  여  대전   중         34.8     288.0         2     2
# 2   2024-01-03  남  서울   하         57.2     274.0         8     0
# 3   2024-01-04  남  대전   중         45.1     329.0         7     1
# 4   2024-01-05  남  서울   상         23.8     341.0         4     0
# ..         ... ..  ..  ..          ...       ...       ...   ...
# 145 2024-05-25  남  광주   중         41.5     323.0         5     0
# 146 2024-05-26  남  부산   상         57.5     336.0         4     1
# 147 2024-05-27  남  대전   중         33.5     266.0         6     1
# 148 2024-05-28  남  서울   중         33.3     358.0         8     0
# 149 2024-05-29  여  광주   하         35.2     220.0         4     0
#
# [150 rows x 8 columns]

# %% [markdown]
# 날짜 열을 datetime 으로 바꾸는 방법

# %%
data["날짜"] = pd.to_datetime(data["날짜"])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   날짜           150 non-null    datetime64[ns]
#  1   성별           150 non-null    object
#  2   지역           150 non-null    object
#  3   만족도          150 non-null    object
#  4   평균 체류 시간(분)  150 non-null    float64
#  5   월 수입(만원)     150 non-null    float64
#  6   방문 페이지 수     150 non-null    int64
#  7   자녀 수         150 non-null    int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(3)
# memory usage: 9.5+ KB

# %%
fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(data["날짜"], data["평균 체류 시간(분)"], marker="o")
ax.set_title("날짜별 평균 체류 시간 변화 그래프")
ax.set_xlabel("날짜")
ax.set_ylabel("평균 체류 시간(분)")
plt.show()

# %%
plt.figure(figsize=(3, 3))
sns.countplot(data=data, x="성별")
plt.title("성별에 대한 막대그래프")
plt.show()

# %%
user = input("입력값: ")
num = 20 + int(user)

# %%
fig, ax = plt.subplots(1, 3, figsize=(10,3))
# 첫번째 그래프: 자녀 수에 대한 막대 그래프
sns.countplot(data=data, x="자녀 수", ax=ax[0])
ax[0].set_title("자녀 수에 대한 막대그래프")
# 두번째 그래프: 평균 체류 시간(분)에 대한 히스토그램
ax[1].hist(data["평균 체류 시간(분)"], edgecolor="black")
ax[1].set_title("평균 체류 시간(분)에 대한 히스토그램")
# 세번째 그래프: 월 수입(만원)에 대한 상자그림
ax[2].boxplot(x=data["월 수입(만원)"])
ax[2].set_title("월 수입(만원)에 대한 Box Plot")
ax[2].set_xlabel("월 수입(만원)")
# Out:
# Text(0.5, 0, '월 수입(만원)')
